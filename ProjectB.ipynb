# %%
import numpy as np

# %% [markdown]
# *Inizialization of parameters*

# %%
C = np.array ([[4, -1], [-1, 4]])
C_inv = np.linalg.inv (C)
mean = [0, 0]

a = [1, 3, 10]
n = 100000

Y = np.zeros (n)
L = np.zeros (3)
U = np.zeros (3)

# %% [markdown]
# *Generating n standard normal random variables*

# %%
seed = 42
gen = np.random.default_rng(seed)
Z = gen.multivariate_normal (mean, C, size=n)

# %% [markdown]
# ### (a)

# %%
for i in range (3):
    # generate Y = 1 {Z that belongs to A}
    Y = np.logical_and (Z[:, 0]>a[i], Z[:, 1]>a[i])

    # calculate the mean estimator of Y
    mu = np.mean(Y)

    # calculate the standard deviation estimator of Y
    X = (Y - mu)**2
    sd = np.sqrt ( sum (X) / (n-1) )

    # calculate the Lower bound of the 95% confidence interval
    L[i] = mu - 1.96 * sd / np.sqrt(n)

    # calculate the Lower bound of the 95% confidence interval
    U[i] = mu + 1.96 * sd / np.sqrt(n)

# %% [markdown]
# *Print the 95% confidence interval for each a*

# %%
for i in range(3):
    print (f'The 95% confidence interval with a = {a[i]} is [{L[i]}, {U[i]}]')
# Out:
# The 95% confidence interval with a = 1 is [0.06544044719330609, 0.0685395528066939]
# The 95% confidence interval with a = 3 is [0.0012509286211408977, 0.0017290713788591023]
# The 95% confidence interval with a = 10 is [0.0, 0.0]

# %% [markdown]
# ### (b)

# %% [markdown]
# *Observe that the point $b \in A$ that maximizes the N(0, C) is the point b = (a, a)*

# %%
for i in range (3):
    b = np.array ([a[i], a[i]])
    # generating r.v. distributed as g
    seed = 42
    gen = np.random.default_rng(seed)
    Z_shift = gen.multivariate_normal (b, C, size=n)

    Lx = np.exp (- b @ C_inv @ Z_shift.T + 0.5 * (b @ C_inv @ b.T).item() )
    
    # generate Y = 1 {Z that belongs to A}
    Y = np.logical_and (Z_shift[:, 0]>a[i], Z_shift[:, 1]>a[i])

    # calculate the mean estimator of Y
    mu = np.mean(Y*Lx)

    # calculate the standard deviation estimator of Y
    X = (Y*Lx - mu)**2
    sd = np.sqrt ( sum (X) / (n-1) )

    # calculate the Lower bound of the 95% confidence interval
    L[i] = mu - 1.96 * sd / np.sqrt(n)

    # calculate the Lower bound of the 95% confidence interval
    U[i] = mu + 1.96 * sd / np.sqrt(n)

# %% [markdown]
# *Print the 95% confidence interval for each a*

# %%
for i in range(3):
    print (f'The 95% confidence interval with a = {a[i]} is [{L[i]}, {U[i]}]')
# Out:
# The 95% confidence interval with a = 1 is [0.06495905289225598, 0.06671900247415866]
# The 95% confidence interval with a = 3 is [0.0013743199536587621, 0.0014309747921187135]
# The 95% confidence interval with a = 10 is [1.1374357689063062e-17, 1.2628193488207622e-17]

# %% [markdown]
# ### (c)

# %% [markdown]
# *We just want to analyse the difference by considering as covariance matrix $\delta \cdot C$ for different values of $\delta \in \mathbb{R}$*

# %%
delta = 0.01
C = delta*C
C_inv = np.linalg.inv (C)

# %%
for i in range (3):
    b = np.array ([a[i], a[i]])
    # generating r.v. distributed as g
    seed = 42
    gen = np.random.default_rng(seed)
    Z_shift = gen.multivariate_normal (b, C, size=n)

    Lx = np.exp (- b @ C_inv @ Z_shift.T + 0.5 * (b @ C_inv @ b.T).item() )
    
    # generate Y = 1 {Z that belongs to A}
    Y = np.logical_and (Z_shift[:, 0]>a[i], Z_shift[:, 1]>a[i])

    # calculate the mean estimator of Y
    mu = np.mean(Y*Lx)

    # calculate the standard deviation estimator of Y
    X = (Y*Lx - mu)**2
    sd = np.sqrt ( sum (X) / (n-1) )

    # calculate the Lower bound of the 95% confidence interval
    L[i] = mu - 1.96 * sd / np.sqrt(n)

    # calculate the Lower bound of the 95% confidence interval
    U[i] = mu + 1.96 * sd / np.sqrt(n)

# %% [markdown]
# *Print the 95% confidence interval for each a*

# %%
for i in range(3):
    print (f'The 95% confidence interval with a = {a[i]} is [{L[i]}, {U[i]}]')
# Out:
# The 95% confidence interval with a = 1 is [1.137435768906302e-17, 1.2628193488207574e-17]
# The 95% confidence interval with a = 3 is [1.817633911580413e-134, 2.4970789259215533e-134]
# The 95% confidence interval with a = 10 is [0.0, 0.0]

# %% [markdown]
# I want to cycle (c) for different values of $\delta$. For simplicity I consider only a = 1.

# %%
#for delta in [0.01, 0.1, 1, 10, 100]:
L = np.zeros(5)
U = np.zeros(5)
C = np.array ([[4, -1], [-1, 4]])
delta = 0.001
C = delta*C

for i in range (5):
    C = 10 * C
    C_inv = np.linalg.inv (C)
    b = np.array ([1, 1])

    # generating r.v. distributed as g
    seed = 42
    gen = np.random.default_rng(seed)
    Z_shift = gen.multivariate_normal (b, C, size=n)

    Lx = np.exp (- b @ C_inv @ Z_shift.T + 0.5 * (b @ C_inv @ b.T).item() )
    
    # generate Y = 1 {Z that belongs to A}
    Y = np.logical_and (Z_shift[:, 0]>1, Z_shift[:, 1]>1)

    # calculate the mean estimator of Y
    mu = np.mean(Y*Lx)

    # calculate the standard deviation estimator of Y
    X = (Y*Lx - mu)**2
    sd = np.sqrt ( sum (X) / (n-1) )

    # calculate the Lower bound of the 95% confidence interval
    L[i] = mu - 1.96 * sd / np.sqrt(n)

    # calculate the Lower bound of the 95% confidence interval
    U[i] = mu + 1.96 * sd / np.sqrt(n)

    print (f'The 95% confidence interval for delta = {delta} is [{L[i]}, {U[i]}]')
# Out:
# The 95% confidence interval for delta = 0.001 is [1.137435768906302e-17, 1.2628193488207574e-17]
# The 95% confidence interval for delta = 0.001 is [0.0009120728728264974, 0.0009509152940949922]
# The 95% confidence interval for delta = 0.001 is [0.06495905289225598, 0.06671900247415866]
# The 95% confidence interval for delta = 0.001 is [0.15210111394982248, 0.15582865459464393]
# The 95% confidence interval for delta = 0.001 is [0.19053298192348211, 0.19514095786417957]
